# %% [markdown]
# # 프로젝트 목표
# 데이터 사이언스 분야에 대해 이해하기
# 데이터 사이언스에서 자주 사용되는 패키지 사용해보기
# 1. Google 주식 데이터를 다운로드 받습니다
# 2. 데이터 사이언스에서 자주 사용되는 패키지를 사용하여
# 3. 원하는 데이터만 뽑아내서 차트로 출력합니다.
#
# # 데이터 사이언스
# 다양한 데이터로부터 새로운 지식과 정보를 추출하기 위해
# 과학적 방법론, 프로세스, 알고리즘, 시스템을 동원하는 융합 분야
# - 수학 및 통계에 대한 지식
# - 도메인 전문성
# - 해킹 실력
#
# ## 데이터 사이언스 프로세스
# 필요한 정보를 추출하는 5단계
# 1. 문제 정의: 해결하고자 하는 문제 정의
# 2. 데이터 수집: 문제 해결에 필요한 데이터 수집
# 3. 데이터 전처리(정제): 실질적인 분석을 수행하기 위해 데이터를 가공하는단계 / 수집한 데이터의 오류제거(결측치,이상치), 데이터 형식 변환 등
# 4. 데이터 분석: 전처리가 완료된 데이터에서 필요한 정보를 추출하는 단계
# 5. 결과 해석 및 공유: 의사 결정에 활용하기 위해 해석하고 시각화 후 공유하는 단계
#
# # 프로세스1.문제정의
# 문제: 구글의 주식 가격은 앞으로 어떻게 될까?
# 어떤 정보를 수집해야 할까?: 1.주가 2.경제지표 3.뉴스 4.재무재표
# # 프로세스2. 데이터수집
# 웹 스크래핑: 웹 페이지에서 데이터를 추출하는 기술(웹사이트주소/robots.txt)
# 웹 크롤링: 웹 페이지를 자동으로 탐색하고 데이터를 수집하는 기술
# Open API 활용: 공개된 API를 통해 데이터를 수집
# 데이터 공유 플랫폼 활용: 다양한 사용자가 데이터를 공유하고 활용할 수 있는 온라인 플랫폼 / 종류: 캐글(kaggle),데이콘(Dacon),공공데이터포털 등
# ## 데이터 수집 - 캐글
# ver1 example
# ## 참고 sdv란?
# 몇 가지 필드를 쉼표로 구분한 텍스트 데이터 및 텍스트 파일
# 표 형식의 데이터를 csv형태로 많이 사용
# window에서 더블클릭으로 열면 excel로 열림. 수정 후 저장하면 깨짐현상 한번씩 발생. 수정을 코드로 할것.
#
# # 프로세스3. 데이터 전처리(정제)
# 오류가 있는 데이터 제거 > 데이터 품질 개선(품질이라 함은 분석에 도움이 되는 데이터가 많으면 품질이 좋다, 필요없는거 많다하면 품질떨어짐)
# 중복 데이터 제거
# Numpy,Pandas,mMatplotlib
# 넘파이: 수학 계산용 패키지, 판다스,맵플러립 을 사용하기 위해 활용하느 ㄴ패키지
# 판다스: 원하는 데이터 추출이나 데이터 분석할때 활용되는 패키지
# Matplot: 그래프를 그려주는 패키지
#
# # Numpy
# 다차원 배열을 쉽게 처리하고 효율적으로 사용할 수 있도록 지원하는 파이썬 패키지
# 장점: 넘파이행렬연산은 데이터가 많을수록 파이썬 반복문에 비해 훨씬 빠르다.
#       다차원 행렬구조를 제공하여 개발하기 편하다.
# 실습파일 1.Numpy.Basic.ipnb
# # Pandas
# Numpy의 한계: 그룹화,피벗 등 구조화가 부족함.
# 내부적으로 넘파이도 사용함. 엑셀을 다루듯 고성능의 데이터구조를 만들 수 있다.
# 엑셀의 파이썬버전
# 넘파이 기반으로 만들어진 패키지로,
#
# numpy pandas 파일에
#
#
# 알라딘 API 구글에 쳐서, 맨밑에 API키발급 / 주소넣는칸에 127.0.0.1:8000/
# 알라딘API돌아가서 이용메뉴얼 클릭 / 샘플주소 복사후 키넣는칸에 내API키입력 후 웹사이트에 쳐보기 / ? 뒤에 있는 파라미터분석하기(밑에 표보면서 해석해라함) /xml인가 거기에 js 넣으면 딕셔너리로 나옴 /
