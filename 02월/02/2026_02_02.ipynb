# %% [markdown]
# # List
# 과정소개,알고리즘,배열,연습문제,버블정렬
# 자료구조와 알고리즘
# 학습목표: 논리적사고력 향상, 문제해결능력 향상
# 최종목표는 연습문제가 아닌 "현실세계문제"
# 학습도구: Pypy, PyCharm , swea , AI
# # APS(Algorithm Problem Solving) 기본 학습
# - 기초 자료 구조 이해 중심
#   입출력을 제외한 내장함수를 사용하지 않습니다.
#   기본적인 내장함수의 동작원리를 이해합니다.
# - AI 활용 방법
#   교과서가 아닌 학습에 도움을 받는 용도로 사용합니다.
#   문제 전체를 넘기고 코드를 요구해서는 안됩니다,
#   대화를 통해 문제점을 찾도록 작은 단위로 질문해봅시다.
# 다른 사람이 작성한 코드를 많이 읽어보는 것이 중요합니다.
# 코드를 눈으로 보는 것이 아니라 직접 따라 입력해 보세요.
# 코드가 외워질 정도로 반복해야 이해도 잘 할 수 있습니다.
# # 알고리즘
# 문제를 해결하기 위한 절차나 방법입니다.
# ## 의사코드(슈도코드)와 순서도
# 컴퓨터 분야에서 알고리즘을 표현하는 방법
# ## 알고리즘의 성능
# APS 과정의 목표 중 하나: 보다 좋은 알고리즘을 이해하고 활용하기
# 좋은 알고리즘이란?
# "정확성": 얼마나 정확하게 동작하는가
# 주어진 문제를 해결하기 위해 여러 개의 다양한 알고리즘이 가능
# ### 알고리즘 성능 비교 예시
# 1부터 100까지의 합을 구하는 문제:
# ## 알고리즘의 시간 복잡도
# 알고리즘의 작업량을 표현할 때 시간 복잡도로 표현합니다.
# 연산횟수를 기준으로 계산
# ## 시간 복잡도 표시
# 빅-오 표기법
# 시간 복잡도 함수 중에서 가장 큰 영향력을 주는 n에 대한 항만을표시
# 계수는 생략
# ### 빅-오 표기법
# # 배열(Array)
# 일정한 자료형의 변수들을 하나의 이름으로 열거하여 사용하는 자료구조
# ## 배열의 필요성
# 프로그램 내에서 여러 개의 변수가 필요할 때
# ## 1차원 배열
# 배열을 선언할 떄는 프로그램에서 사용할 배열 이름이 필요합니다.
# 그리면서 연습이 중요.
# ## 입력받은 정수를 1차원 배열에 저장하는 방법
# 첫 줄에 양수의 개수 N이 주어집니다,
# 다음 줄에 빈칸으로 구분된 N개의 양수 Ai가 주어집니다.
# N = int(input())
# arr = list(map(int,input().split()))
# ## 배열 원소의 합 s 계산하기
# s = 0
# for i in range(N):
#     s += arr[i]
# ## 배열 원소 중 최댓값 max_v 찾기
# ## 배열 원소 중 최댓값의 인덱스 max_idx 찾기
# max_idx = 0
# for i in range(1,N):
#     if arr[max_idx] < arr[i]:
#         max_idx = i
# ### 최댓값이 여러 개인 경우 마지막 max_idx 찾기
# 크거나같다로 변경
# ## 찾는 값이 배열에 있으면 해당 원소의 인덱스, 없으면 -1을 idx에 넣기
# 6 5
# 2 7 5 3 1 7
# N, V = map(int, input().split())
# arr = list(map(int,input().split()))
#
# - 5를 찾는 경우
#   idx = -1 # 찾는 값이 없다고 가정
#   for i in range(N):
#       if arr[i] == V:
#           idx = i
#           break         # for i (뭘 중지시키는건지 주석)
# # 연습문제
# ## 연습문제1
# N개의 양의 정수에서 가장 큰 수와 가장 작은 수의 차이를 출력하세요.
# - 첫 줄에 테스트 케이스의 수 T가 주어진다.
# - 각 케이스의 첫 줄에 양수의 개수 N이 주어진다.
# - 다음 줄에 N개의 양수 ai가 주어진다.
#
# - 각 줄마다 "#T"뭐시기\
#
# 3
# 5
# 477162 658880 ~
# 5
# 565469 ~
# 10
# 784386 ~
#
# ## 연습문제2
# 배열 활용 예제: Gravity
# 9
# 7 4 2 0 0 6 0 7 0
# 어떤원소 arr[i]의 오른쪽에 더 작은 수의 개수 == 낙차
# 낙차의 최댓값
#
# # 버블 정렬
# 정렬(Sort): 2개 이상의 자료를 키(특정 기준)에 의해 작은 값부터 큰 값(오름차순) 혹은 그 반대의 순서대로(내림차순) 재배열하는 알고리즘.
# 버블 정렬, 카운팅정렬, 선택정렬, 퀵정렬, 병합정렬
# - 인접한 두 개의 원소를 비교하며 자리를 계속 교환하는 방식
#   첫 번째 원소부터 인접한 원소끼리 계속 자리를 교환하면서 맨 마지미가 자리까지 이동한다
#   한 단계가 끝나면 가장 큰 원소가 마지막 자리로 정렬된다.
#   교환하며 자리를 읻옹하는 모습이 물 위에 올라오는 거품 모양과 같다고하여 버블정렬.
# - 시간 복잡도 O(n제곱)
# [55,7,78,12,42]를 정렬하는 과정(오름차순)
# 첫 번째 단계: 두개비교이동, 두개비교이동, ,,, 하면 젤큰수가 젤오른쪽배치됨.
# 두 번째 단계: 두개비교이동, 두개비교이동 ,,, 마지막인덱스-1 자리까지 반복.
# 세번째단계: 마지막인덱스-2 까지 반복
# *정렬할 구간이 점점 줄어든다*
# BubbleSort(a,N)
# for i : N-1 -> 1
#     for j : 0 -> i-1
#         if a[j] 뭐시기
#
# def bubble_sort(a,N):
#     for i in range(N-1,0,-1)
#         for j in range(i):
#             if a[j] > a[j+1]:
#                 a[j], a[j+1] = a[j+1], a[j]

# %%
#테스트 케이스의 개수
T = int(input())


# 아이디어: 요소의 바로 양옆 2칸이 그 요소보다 작아야함. 


for tc in range(1, 1+T):
    N = int(input())
    arr = list(map(int, input().split()))

    for i in range(2,N-2):
            # 만약 i번째 건물의높이가 왼쪽2개,오른쪽2개보다 높으면
            if arr[i] > arr[i-1] and arr[i] > arr[i-2] and arr[i] > arr[i+1] and arr[i] > arr[i+2]:
                # 인접한 4개의 건물의 높이를 리스트로 만듦
                lst = [arr[i-2], arr[i-1], arr[i+1], arr[i+2]]
                # 4개중의 최댓값을 구해 max_v에 할당한다.
                max_v = lst[0]
                for j in lst:
                    if j > max_v:
                        max_v = j
                # i번째 건물의높이에서 max_v를 뺀 값을 k에 할당한다.
                k = arr[i] - max_v
                #합만 갱신하면됨.
# Out:
# [0, 1, 2]
