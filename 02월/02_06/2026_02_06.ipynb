# %% [markdown]
# # 코드체계
# 문자에 대응되는 숫자를 정한 것입니다
# ASCII
#
# # 문자열의 분류
# - Length-Controlled 문자열
#   문자열의 길이 정보를 함께 저장해서, 그 길이만큼 문자 데이터를 읽는 방식입니다.- Java, Python
# - Delimited 문자열
#   문자열의 끝을 나타내는 특정한 구분자가 있어서, 구분자가 나올 때까지 문자열로 인식합니다. - C언어
#
# # 파이썬 str 클래스 구조
# 길이 외에 다른 정보도 저장
# - PyObject_HEAD: 모든 Python객체가 상속하는 공통 구조
# - length
# - hash: 문자열의 해시값으로, 딕셔너리 키로 쓸 때 사용됩니다.
# - interned: 같은 문자열을 관리하는 플래그
# - kind: 문자열 인코딩의 크기
# - data: 문자열이 저장된 실제 메모리 주소를 가리키는 포인터
# ## C언어에서 문자열
# 문자열은 문자들의 배열 형태로 구현된 응용 자료형.
# ## Java 에서의 문자열
# ## python3 에서의 문자열
# 문자열은 튜플과 같이 요소값을 변경할 수 없음.(immutable)
# ## C, Java, Python 문자열의 차이
# C는 아스키코드로 저장
# Java는 유니코드(UTF-16, 2-Byte)f\로 저장
# Python3는 유니코드(UTF-8)
# # Python 에서의 문자열 입력
# input() 함수로 읽기
# text = input()
# Hello python을 입력하면 빈칸을 포함해 한 행을 읽어 들입니다.
# text = list(input())을 사용하면 각 글자가 리스트의 원소로 저장
# 원소별로 다른 글자로 변경가능(리스트로 바꾸면)
