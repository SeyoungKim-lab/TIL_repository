# %% [markdown]
# # Function call
# 후입선출 구조의 스택을 이용하여 수행순서 관리
# # Stack 기반 문제 해결 기법
# ## 재귀 호출
# 함수가 자신과 같은 작업을 반복해야 할때, 자신을 다시 호출하는 구조
# 자신을 다시호출 => 똑같이생긴 다른함수를 호출한다고 생각
# # 피보나치 수열
# 0과 1로 시작하고 이전 두수의 합을 다음 항으로 하는 수열
# ## 피보나치 수열의 수학적 정의
# F0 =1 F1 =1
# Fi = Fi-1 + Fi-2, for i>=2
# # 재귀함수의 기본형
# 현재단계 i, 목표N
# 기본형 숙지
# ## 모든 배열 원소에 접근하는 재귀함수
# 재귀함수는 한단계씩 갔다가 한단계씩 리턴하는 방식
# # 배열 원소 검색
# 배열에 v가 있으면 1, 없으면 o을 리턴하는 함수
# f(i,N,v) arr[i]에 v가 있는지 찾는 함수
# 호출하면 오른쪽(함수의처음부터), 리턴하면 왼쪽(끝난위치부터)
# # Memoization
# 이전에 계산한 값을 메모리에 저장해서 매번 다시 계산하지 않도록 하여 전체적인 실행속도를 빠르게 하는 기술
# # DP
# 동적계획법(Dynamic Programming)
# 입력 크기가 작은 부분 문제들을 먼저 해결한뒤, 그 결과를 바탕으로 더 큰 부분 문제를 차례대로 해결해 나가며 최종적으로 전체 문제의 해답을 도출하는 알고리즘
# # DFS
# 비선형 자료구조 탐색
# 1. 깊이우선탐색 : DFS
# 2. 너비우선탐색
# 그림을 보면서 손으로 따라가기까지
# 한 방향으로 가능한 한 깊이 탐색한 후, 더 이상 갈 곳이 없으면 되돌아와 다른 방향을 탐색
# ## 동작원리
# 1. 시작 정점의 한 방향으로 갈 수 있는 경로 있는 곳까지 깊이 탐색해 나간다.
# 2. 더 이상 갈 곳이 없으면, 가장 마지막에 만났던 갈림길 간선이있는 정점으로 돌아와서 다른 방향의 정점으로 탐색을 계속 반복하여 결국 모든 정점을 방문하는 탐색방법.
