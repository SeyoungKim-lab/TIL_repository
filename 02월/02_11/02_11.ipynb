# %% [markdown]
# # 스택을 활용한 계산기 프로그램을 만들 수 있다.
# ## 후위 표기법 변환
# step1. 중위 표기법(a+b)의 수식을 후위 표기법(a b +)으로 변경한다. (stack이용)
# ## 중위 표기법의 후위 표기법 변환 방법1
# 1. 괄호를 사용하여 다시표현(손으로변환)
# 2. 각 연산자를 그에 대응하는 오른쪽 괄호의 뒤로 이동시킨다.
# 3. 괄호를 제거한다.
# ## 중위 표기법의 후우 ㅣ표기법 변환 방법 2 (stack이용)
# 입력받은 중위표기법에서 토큰을 읽는다.(토큰: 데이터처리 기본단위)
# 토큰이 피연산자면 토큰을 출력한다.(피연산자면 3 ,4 이런숫자)
# 토큰이 연산자(괄호포함)일 때,
# ## 후위 표기법 변환
# ## 후기 표기법 연산
# 1. 피연산자를 만나면 스택에 push
# 2. 연산자를 만나면 필요한 만큼의 피연산자를 스택에서pop하여 연산하고 연산결과를 다시 스택에 pushㅗ한다.
# 3. 수식이 끝나면 마지막으로 스택을pop하여 출력한다.
# # Stack 응용
# ## Backtracking
# DFS와 비슷한데 효율적이다?
# 인접한 곳의 정점을 가져오는게 아니라 생성을 해나간다?
# 재귀기반의 DFS이다.
# 원하는 해를 찾으면 yes or no 반환하고 종료하는 경우
# 상태공간트리를 구성하여 그걸 DFS로 탐색
# Pruning(가지치기) : 이쪽 굳이 안가봐도 되겠는데?
# 경우의 수가 많은 문제의 경우
