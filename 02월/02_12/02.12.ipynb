# %% [markdown]
# # 백트래킹 이란?
# 후보해를 구성해 나가다가 더 이상 해가 될 수 없다고 판단 => 되돌아가서 다른후보찾기
# ## 백트래킹과 DFS
# DFS는 모든노드에 대한 탐색
# 상태공간트리를 직접 형성해야함
# ## 부분집합
# 어떤 집합의 공집합과 자기자신을 포함한 모든 부분
# ## 백트래킹 기법으로 powerset 만들기
# # 단순하게 순열을 생성하는 방법
# # 가지치기
#
# # 순열2
