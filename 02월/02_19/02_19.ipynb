# %% [markdown]
# # 트리
# 한개 이상의 노드로 이루어진 유한 집합
# 노드, 잎노드
# 간선(edge): 부모노드와 자식노드를 연결
# 루트노드 - 트리의 시작노드
# 형제노드 - 같은부모노드의 자식노드들
# 조상노드 - 간선따라 루트노드까지 이르는 모든 노드들
# 서브트리 - ?
# 자손노드 -
# ## 트리의 차수
# 자식노드의 층수?
# 노드의 높이: 걍 층수
# 트리의 높이: 가장높은높이값
# # 이진트리
# 모든노드들이 2개이내의 서브트리갖는트리
# -왼쪽자식, 오른쪽자식
# # 포화이진트리
# 모든레벨에 꽉차있는거
# # 완전이진트리
# 포화이진트리를 따르면서, 1~n번중 빠진정점이 없는거
# # 편향이진트리
# 왼쪽편향이진트리, 오른쪽편향이진트리
# # 이진트리표현1
# 배열을 이용한 이진트리의 표현
# # 자식번호를 인덱스로 부모번호를 저장
