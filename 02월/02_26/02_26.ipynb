# %% [markdown]
# # Bootstrap
# 프레임워크 : 뼈대를 미리 제공해주는 개발환경
# 부트스트랩: 다양한 기기환경에서 웹페이지 적절표시 반응형 웹디자인 지원도구
# ## CDN(Content Delivery Network)
# 오리진서버 - 엣지서버
# # Reset CSS
# 브라우저마다 stylesheet이 상이하다는 문제점을 고치기위해
# ## Normalize CSS
# 웹표준지원하지 않는애한테 맞춰주는방식
# bootstrap-reboot.css <==
# ## Bootstrap 활용
# ### Typography
# ### Bootstrap Color System
# ## Component
# 재사용 가능한 독립적인 부품(=레고블록)
# 로그인버튼,검색창,네비게이션바 등
# ## modal
#
# # Semantic web
# 요소의 시각적측면이 아닌 요소의 목적과 역할에 집중하는 방식
# ## HTML 요소가 의미를 가진다는 것
# <h1> 최상위제목이라는 의미
# 검색엔진 및 개발자가 알기쉽게 해준다.
# 아무의미없는 div에 의미를 더해주는 애들
# : 기능자체는 div와 100% 같음
# : header, nav, main, article, section, footer, aside 등
#
# ## CSS에서
# ### CSS방법론
# 일련의 가이드라인
# OOCSS: Object Oriented CSS
# 객체 지향적 접근법을 적용하여 CSS를 구성
# .button
# .button-blue
# .button-red
# 이런식으로 구조와 색상을 분리하자.
# 컨테이너와 콘텐츠 분리:
