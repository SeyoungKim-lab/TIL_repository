# %% [markdown]
# # Union-Find
# - 서로소 집합: 교집합이 없다.
# - 대표자(representative):
# - 표현방법: 연결리스트 또는 트리로 대표자표현
#
# # 서로소 집합 연산
# 반        1      2     3     4     5
# 대표자   강사1 강사2 강사3 강사4 강사5
#
# Union(x,y) 합집합. x가 대표.
#
# 경로압축
# ![image.png](attachment:image.png)
