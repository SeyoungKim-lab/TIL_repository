# %% [markdown]
# # 모듈(Module): 한 파일로 묶인 변수와 함수의 모음
# 특정한 기능을 하는 코드가 작성된 파이썬 파일(py.)
# ## math 내장 모듈
# 파이썬이 미리 작성해둔 수학 관련 변수와 함수가 작성된 모듈
# import math
# print(math.pi) #3.141592...
# print(math.sqrt(4)) #2.0
# 즉,math라는 모듈 안에는 pi라는 변수, sqrt라는 함수가 이미 정의되어있다.
# ## import 문 사용
# '.(dot)'연산자: 점의 왼쪽 객체에서 점의 오른쪽 이름을 찾아라 라는 의미
# 같은 이름의 함수가 여러 모듈에 있을 때 충돌을 방지할 수 있음
# 즉, #모듈명.변수명/#모듈명.함수명
# ## from 절 사용
# from math import pi, sqrt
# print(pi)
# print(sqrt(4))
# 이러면 괄호안 모듈명을 안써도됨.
# 근데 단점은 명시적으로 그 변수가 어디껀지 알기어려움.
# ### from 절 사용시 주의사항
# 서로 다른 모듈에서 import된 변수나 함수의 이름이 같은 경우 이름충돌발생
# from math import sqrt
# from my_math import sqrt
#
# frpm math improt * 하면 모든함수가져옴
#
# ### 'as'키워드 : 별칭부여
# from math import sqrt
# from my_math import sqrt as my_sqrt
#
# ## 사용자 정의 모듈
# 지금까지는 bulit in 모듈이었고..
# ### 직접 정의한 모듈 사용하기
# #my_math.py
# def add(x,y)
#     return x+y
#
# import my_math  ~~~~~
#
# # 파이썬 표준 라이브러리(PSL)
# 모듈들을 모은게 "패키지"(폴더)
# 패키지와 잔잔바리모듈 다 모은게 "라이브러리"
# 파이썬 언어와 함께 제공되는 다양한 모듈과 패키지의 모음(예를들어 math모듈)
# http://docs.python.org/ko/3/library/index.html
# 패키지는 이미 누군가가 잘 만들어둔 코드 꾸러미라고 생각하면 된다.
# - 직접 패키지 만들어보기
# - from 폴더1.폴더1-(1).폴더1-(2) import 모듈
# 파이썬을 설치하면 자동으로 사용할 수 있는 기본 라이브러리
# 이 기본 라이브러리에는 다양한 모듈과 패키지가 포함됨.
# 별도 설치 없이 바로 import 해서 사용가능
#
# # 파이썬 외부 패키지(Third-party Package)
# - 직접 설치해서 쓰는 패키지
#   ## pip
#   외부 패키지들을 설치하도록 도와주는 파이썬의 패키지 관리 시스템
#   $ pip install SomePackage
#   requests 외부 패키지 설치 및 사용 예시
#   requests패키지: 파이썬에서 웹에 요청을 보내고 응답을 받는걸 아주 쉽게 만들어주는 외부 패키지
#   $ pip install requests
#
# # 제어문
# 코드의 실행 흐름을 제어하는 데 사용되는 구문
# 조건에 따라 코드 블록을 실행하거나 반복적으로 코드를 실행
# 예를들어 게임에서 점수가 높으면 "축하합니다"라는 메시지를 띄우고(조건), 해당 메시지를 5번 깜빡이고 싶을때(반복) 사용합니다
# 그리고 게임을 계속할 것인지 종료할 것인지를 선택할 때도 제어문이 사용.
# ## 조건문 : if, elif, else
# if score >= 90:
#    message = "축하합니다! 최고입니다!"
# elif score >= 70:
#      print
# else:
#      print
# ## 반복문 : for 반복, while 반복, 반복문제어키워드(break,continue)
# ## 조건문이란: 주어진 조건식을 평가하여 해당 조건이 참인 경우에만 코드블록을 실행하거나 건너뜀
# if/ elif / else
# ### if
# if문: 조건문의 기본형태, if문에 작성된조건을 만족할때 내부코드실행, 작성되는 조건은 표현식으로 작성
# elif문: 이전의 조건을 만족하지 못하고 추가로 다른 조건이 필요할 때 사용, 여러 개의 elif 문을 사용할 수 있음
# else문: 모든 조건들을 만족하지 않으면 실행됨(조건이 없다)
# ### 조건문의 예시
# 게임 점수가 95점 초과일 때 '축하합니다.'를 출력
# 게임 점수가 95점 이하일 때는 '수고하셨습니다.'를 출력
# 최종 게임 점수를 출력
# if내부에 if 가능
# ## 반복문(오늘의 메인dish)
# 주어진 코드 블록을 여러 번 반복해서 실행하는 구문
# - 반복문의 종류
#   for문
#   반복가능한 객체의 요소들을 반복하는데 주로 사용
#   주로 반복가능한 객체 요소의 개수만큼 반복
#   특징: 반복횟수가 정해져 있음
#   for 변수 in 리스트:
#       print(변수)
#   하면 리스트의 인덱스수만큼 반복. 반복할때마다 각인덱스를 변수에 할당.
#   while문
#   while조건이 참인동안 반복
#   반복횟수가 정해지지 않은 경우주로 사용
#   거짓이 될때까지 계속 반복
#   input_value = ''
#   while input_value != 'exit'
#       input_value = input("Enter a value: ")
#       print(input_value)
#   exit을 입력하면 종료(이해x)
#   ### 반복가능한객체(iterable)
#   요소를 하나씩 반환할 수 있는 모든 객체
#   시퀀스뿐만아닌 비시퀀스(dict,set)등도 반복가능
#   5번반복 이런거는 range를 이용
#   흐름을 깨고 돌기 때문에 제어문이라 불림
#   ### range순회
#   특정 숫자 범위만큼 반복
#   for i in range(5):
#   print(i)
#    <!-- 0 1 2 3 4  -->
#    ### dic 순회: 얘는 각 인덱스의 키를추출
#    ### for i in range(len(number)) 이용할수도있따
# ### 중첩된 반복문
# 중첩된 반복문에서의 출력 예상해보기
# outer = ['A', 'B']
# inner = ['c' , 'd']
#
# for outer in outers:
#     for inner in inners:
#         print(outer, inner)
# 안쪽먼저 끝나야 바깥쪽돈다.
#
# 중첩리스트 순회
# 리스트안의 모든 하나하나의 요소를 다뽑고싶으면
# for in 을 중첩합세다
#
# # while반복문
# 조건식이 참인동안반복 == 조건식이 거짓이 될때까지 반복
# 몇번돌지에 대한 고민보다는 언제끝날지에대한 고민
# 반드시 "종료조건"이 필요
#
# # for 와 while
# for 은 반복가능한 요소를 하나씩 순회하며 반복
# while은 반복횟수가 불명확 or 조건에 따라 반복을 종료해야할경우
#
# # 반복제어
# for문과 while문은 매 반복마다 본문 내 모든 코드를 실행하지만 때때로 일부만 실행하는 것이 필요할 때가 있음.
# - break
#    반복을 끝낸다
# - continue
#    반복으로 돌아간다.
# continue는 리스트에서 원하는것만 뽑는경우?
# breaks는 최초로 만난 무언가를 뽑는다?
#
# pass : 코드짤때 공란으로 남겨놓고 밑에꺼작업할때 pass써두면 틀유지.
#
# # 유용한 내장함수 map & zip
# - map(function, iterable)
#   iterable의 각각의 인덱스들이 function의 인자로 할당
#   list(map()) map도 리스트형태로.
#
# - zip(*iterables)
#   *은 여러개의 반복가능한 객체
