# %% [markdown]
# 1. Positional Arguments(위치인자)
# 함수 호출 시 인자의 위치에 따라 전달되는 인자
# 위치 인자는 함수 호출 시 반드시 값을 전달해야함
#
# 2. Default Argument Values(기본 인자 값)
# def greet(name, age=30)
#     print(f'안녕하세요, {name}님! {age}살이시군요.')
#
# greet('Bob') # 30
#
# 3. Keyword Arguments(키워드 인자)
# def greet(name,age):
#     print(f'~~')
#
# greet(age=35, name= 'Dave') : 이러면 순서달라도 알맞게 할당됨
#
# 4. Arbitary Argument List(임의의 인자 목록)
# def cal_sum(*args)
# print(args) # (1,100,5000,30)
# print(type(args)) # <class 'tuple'>
#
# 5. 임의의 키워드 인자 목록
# def print_info(**kwargs):
#     print(kwarges)
#
# print_info(name='Eve', age=30) #{'name':'Eve' , 'age':30}
#
# ## 함수 인자 권장 작성 순서
# 위치 - 기본 - 가변 - 가변 키워드
#
# # 재귀함수
# ## 재귀함수예시 - 팩토리얼
# 재귀함수는 바디 안에서 자기자신을 호출하는 원리
#
# # 내장함수(Built-in function) : 파이썬에 기본적으로 내장된 함수(별도의 import 없이 즉시 사용가능)
#
#
# # 함수와 Scope(영역)
# 함수는 코드 내부에 local scope를 생성하며, 그 외의 공간인 global scope로 구분(들여쓰기를 통해 구분)
# 예시)
# """
# def func():
#     num = 20
#     print('local', num) #local 20
#
# func()
#
# print('global',num) #NameError: name num is not defined
# """
# num은 지역변수: 함수를 호출할때만 살아있음
# 1) local socpe: 지역범위
# 2) Enclosed scope: 지역 범위 한 단계 위 범위
# 3) Global scope: 최상단에 위치한 범위
#
# # 함수이름
# 동사_형용사_명사
# T/F가 리턴값인 함수는 is사용
# 하나의 함수는 한가지 역할만 하도록
#
#
# # 패킹
# 여러개의 데이터를 하나의 컬렉션으로 모아 담는 과정
# 기본원리: 여러개의 값을 하나의 튜플로 묶는 파이썬의 기본 동작
#
# # 언패킹
# 컬렉션에 담겨있는 데이터들을 개별 요소로 펼쳐 놓는 과정
#
# # 함수의 return, 반환의 법칙: 하나의 객체만 반환

# %% [markdown]
# ~~return x+y 는 무슨의미?~~
# ~~return이 없는함수는 어쩌고..~~
#
# ~~def add_number(x,y):~~
#     ~~result = x+y~~
#     ~~return result~~
# ~~에서 result라는 변수를 정의하는 이유~~
#
# ~~LEGB Rule퀴즈~~
#
# Global 키워드 주의사항-1 이해x
#
# 재귀함수
